# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist,fashion_mnist
from tensorflow.keras.models import Model


def applyPreprocess(inputs):
    # To Normalize and Reshape the input data 
    inputs = inputs.astype("float32") / 255.0
    inputs = np.reshape(inputs, (len(inputs), 28, 28, 1))
    return inputs


def addNoise(data):
    # To Add noise to the input
    noise_factor = 0.2
    noisy_data = data + noise_factor * np.random.normal(
        loc = 0.0, scale = 1.0, size = data.shape
    )
    return np.clip(noisy_data, 0.0, 1.0)


def display(array1, array2):
    # Display N random images from the data
    n = 10

    indices = np.random.randint(len(array1), size=n)
    images1 = array1[indices, :]
    images2 = array2[indices, :]

    plt.figure(figsize=(20, 4))
    for i, (image1, image2) in enumerate(zip(images1, images2)):
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(image1.reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(image2.reshape(28, 28))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    plt.show()

# %%
# Since we only need images from the dataset to encode and decode, we
# won't use the labels.

# Data loading
(mnist_train_data, _), (mnist_test_data, _) = mnist.load_data()
(fmnist_train_data,_), (fmnist_test_data,_) = fashion_mnist.load_data()


# Normalize and reshape the data
mnist_train_data = applyPreprocess(mnist_train_data)
fmnist_train_data = applyPreprocess (fmnist_train_data)

mnist_test_data = applyPreprocess(mnist_test_data)
fmnist_test_data = applyPreprocess(fmnist_test_data)

# Create a copy of the data with added noise
noisy_mnist_train_data  = addNoise(mnist_train_data)
noisy_fmnist_train_data  = addNoise(fmnist_train_data)
noisy_mnist_test_data = addNoise(mnist_test_data )
noisy_fmnist_test_data = addNoise(fmnist_test_data)

# Display the train data and a version of it with added noise
display(mnist_train_data, noisy_mnist_train_data)
display(fmnist_train_data, noisy_fmnist_train_data)

# %%
# Training Model

# Input
input = layers.Input(shape=(28, 28, 1))

# Encoder
x = layers.Conv2D(32, (4, 4), activation="relu", padding="same")(input)
x = layers.MaxPooling2D((2, 2), padding="same")(x)
x = layers.Conv2D(32, (4, 4), activation="relu", padding="same")(x)
x = layers.MaxPooling2D((2, 2), padding="same")(x)


# Decoder
x = layers.Conv2DTranspose(32, (4, 4), strides=2, activation="relu", padding="same")(x)
x = layers.Conv2DTranspose(32, (4, 4), strides=2, activation="relu", padding="same")(x)

# Output
x = layers.Conv2D(1, (4, 4), activation="sigmoid", padding="same")(x)

# Autoencoder
autoencoder = Model(input, x)
autoencoder.compile(optimizer="adam", loss="binary_crossentropy")
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 32)        544
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        16416
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  conv2d_transpose (Conv2DTra  (None, 14, 14, 32)       16416
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 28, 28, 32)       16416
#  ranspose)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 1)         513
#
# =================================================================
# Total params: 50,305
# Trainable params: 50,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.fit(
    x=noisy_mnist_train_data,
    y=mnist_train_data,
    epochs=60,
    batch_size=200,
    shuffle=True,
    validation_data=(noisy_mnist_test_data, mnist_test_data),
)
# Out:
# Epoch 1/60
# 300/300 [==============================] - 22s 15ms/step - loss: 0.1710 - val_loss: 0.0848
# Epoch 2/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0814 - val_loss: 0.0781
# Epoch 3/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0775 - val_loss: 0.0759
# Epoch 4/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0758 - val_loss: 0.0747
# Epoch 5/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0748 - val_loss: 0.0739
# Epoch 6/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0741 - val_loss: 0.0734
# Epoch 7/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0736 - val_loss: 0.0728
# Epoch 8/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0731 - val_loss: 0.0725
# Epoch 9/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0728 - val_loss: 0.0721
# Epoch 10/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0724 - val_loss: 0.0719
# Epoch 11/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0722 - val_loss: 0.0716
# Epoch 12/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0720 - val_loss: 0.0715
# Epoch 13/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0717 - val_loss: 0.0713
# Epoch 14/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0716 - val_loss: 0.0711
# Epoch 15/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0714 - val_loss: 0.0710
# Epoch 16/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0713 - val_loss: 0.0708
# Epoch 17/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0711 - val_loss: 0.0708
# Epoch 18/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0710 - val_loss: 0.0705
# Epoch 19/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0709 - val_loss: 0.0705
# Epoch 20/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0708 - val_loss: 0.0704
# Epoch 21/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0707 - val_loss: 0.0703
# Epoch 22/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0706 - val_loss: 0.0702
# Epoch 23/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0705 - val_loss: 0.0701
# Epoch 24/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0704 - val_loss: 0.0702
# Epoch 25/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0703 - val_loss: 0.0700
# Epoch 26/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0703 - val_loss: 0.0700
# Epoch 27/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0702 - val_loss: 0.0698
# Epoch 28/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0702 - val_loss: 0.0698
# Epoch 29/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0701 - val_loss: 0.0697
# Epoch 30/60
# 300/300 [==============================] - 4s 15ms/step - loss: 0.0700 - val_loss: 0.0698
# Epoch 31/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0700 - val_loss: 0.0696
# Epoch 32/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0699 - val_loss: 0.0696
# Epoch 33/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0699 - val_loss: 0.0696
# Epoch 34/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0698 - val_loss: 0.0697
# Epoch 35/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0698 - val_loss: 0.0695
# Epoch 36/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0698 - val_loss: 0.0695
# Epoch 37/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0698 - val_loss: 0.0695
# Epoch 38/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0697 - val_loss: 0.0694
# Epoch 39/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0697 - val_loss: 0.0694
# Epoch 40/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0697 - val_loss: 0.0694
# Epoch 41/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0697 - val_loss: 0.0693
# Epoch 42/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0696 - val_loss: 0.0693
# Epoch 43/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0696 - val_loss: 0.0694
# Epoch 44/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0696 - val_loss: 0.0694
# Epoch 45/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0695 - val_loss: 0.0693
# Epoch 46/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0695 - val_loss: 0.0693
# Epoch 47/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0695 - val_loss: 0.0693
# Epoch 48/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0695 - val_loss: 0.0693
# Epoch 49/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0695 - val_loss: 0.0692
# Epoch 50/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0695 - val_loss: 0.0692
# Epoch 51/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0694 - val_loss: 0.0692
# Epoch 52/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0694 - val_loss: 0.0693
# Epoch 53/60
# 300/300 [==============================] - 4s 15ms/step - loss: 0.0694 - val_loss: 0.0692
# Epoch 54/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0694 - val_loss: 0.0691
# Epoch 55/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0694 - val_loss: 0.0691
# Epoch 56/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0693 - val_loss: 0.0691
# Epoch 57/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0693 - val_loss: 0.0692
# Epoch 58/60
# 300/300 [==============================] - 4s 15ms/step - loss: 0.0693 - val_loss: 0.0691
# Epoch 59/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0693 - val_loss: 0.0691
# Epoch 60/60
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0693 - val_loss: 0.0693

# %%
mnist_predictions = autoencoder.predict(noisy_mnist_test_data)
display(noisy_mnist_test_data, mnist_predictions)

# %%
autoencoder.fit(
    x=noisy_fmnist_train_data,
    y=fmnist_train_data,
    epochs=75,
    batch_size=200,
    shuffle=True,
    validation_data=(noisy_fmnist_test_data, fmnist_test_data),
)
# Out:
# Epoch 1/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2721 - val_loss: 0.2686
# Epoch 2/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2653 - val_loss: 0.2666
# Epoch 3/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2641 - val_loss: 0.2657
# Epoch 4/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2633 - val_loss: 0.2652
# Epoch 5/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2629 - val_loss: 0.2648
# Epoch 6/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2625 - val_loss: 0.2644
# Epoch 7/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2622 - val_loss: 0.2642
# Epoch 8/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2619 - val_loss: 0.2639
# Epoch 9/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2617 - val_loss: 0.2638
# Epoch 10/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2616 - val_loss: 0.2636
# Epoch 11/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2614 - val_loss: 0.2634
# Epoch 12/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2613 - val_loss: 0.2633
# Epoch 13/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2611 - val_loss: 0.2632
# Epoch 14/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2610 - val_loss: 0.2631
# Epoch 15/75
# 300/300 [==============================] - 5s 15ms/step - loss: 0.2609 - val_loss: 0.2630
# Epoch 16/75
# 300/300 [==============================] - 5s 16ms/step - loss: 0.2608 - val_loss: 0.2631
# Epoch 17/75
# 300/300 [==============================] - 5s 16ms/step - loss: 0.2608 - val_loss: 0.2629
# Epoch 18/75
# 300/300 [==============================] - 5s 16ms/step - loss: 0.2607 - val_loss: 0.2629
# Epoch 19/75
# 300/300 [==============================] - 5s 16ms/step - loss: 0.2606 - val_loss: 0.2627
# Epoch 20/75
# 300/300 [==============================] - 5s 16ms/step - loss: 0.2605 - val_loss: 0.2627
# Epoch 21/75
# 300/300 [==============================] - 5s 16ms/step - loss: 0.2604 - val_loss: 0.2626
# Epoch 22/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2604 - val_loss: 0.2627
# Epoch 23/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2604 - val_loss: 0.2625
# Epoch 24/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2603 - val_loss: 0.2625
# Epoch 25/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2603 - val_loss: 0.2625
# Epoch 26/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2602 - val_loss: 0.2624
# Epoch 27/75
# 300/300 [==============================] - 5s 16ms/step - loss: 0.2602 - val_loss: 0.2624
# Epoch 28/75
# 300/300 [==============================] - 5s 17ms/step - loss: 0.2601 - val_loss: 0.2623
# Epoch 29/75
# 300/300 [==============================] - 6s 20ms/step - loss: 0.2601 - val_loss: 0.2623
# Epoch 30/75
# 300/300 [==============================] - 7s 22ms/step - loss: 0.2601 - val_loss: 0.2622
# Epoch 31/75
# 300/300 [==============================] - 6s 21ms/step - loss: 0.2601 - val_loss: 0.2622
# Epoch 32/75
# 300/300 [==============================] - 5s 16ms/step - loss: 0.2600 - val_loss: 0.2622
# Epoch 33/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2600 - val_loss: 0.2622
# Epoch 34/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2600 - val_loss: 0.2621
# Epoch 35/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2599 - val_loss: 0.2621
# Epoch 36/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2599 - val_loss: 0.2621
# Epoch 37/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2599 - val_loss: 0.2620
# Epoch 38/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2599 - val_loss: 0.2622
# Epoch 39/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2599 - val_loss: 0.2622
# Epoch 40/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2598 - val_loss: 0.2620
# Epoch 41/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2598 - val_loss: 0.2622
# Epoch 42/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2598 - val_loss: 0.2619
# Epoch 43/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2598 - val_loss: 0.2620
# Epoch 44/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2597 - val_loss: 0.2622
# Epoch 45/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2597 - val_loss: 0.2619
# Epoch 46/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2597 - val_loss: 0.2620
# Epoch 47/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2597 - val_loss: 0.2619
# Epoch 48/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2597 - val_loss: 0.2619
# Epoch 49/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2596 - val_loss: 0.2619
# Epoch 50/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2596 - val_loss: 0.2619
# Epoch 51/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2596 - val_loss: 0.2619
# Epoch 52/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2596 - val_loss: 0.2618
# Epoch 53/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2596 - val_loss: 0.2619
# Epoch 54/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2596 - val_loss: 0.2618
# Epoch 55/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2596 - val_loss: 0.2618
# Epoch 56/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2596 - val_loss: 0.2618
# Epoch 57/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2595 - val_loss: 0.2619
# Epoch 58/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2595 - val_loss: 0.2618
# Epoch 59/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2595 - val_loss: 0.2617
# Epoch 60/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2595 - val_loss: 0.2618
# Epoch 61/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2595 - val_loss: 0.2618
# Epoch 62/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2595 - val_loss: 0.2618
# Epoch 63/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2595 - val_loss: 0.2618
# Epoch 64/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2595 - val_loss: 0.2617
# Epoch 65/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2594 - val_loss: 0.2618
# Epoch 66/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2594 - val_loss: 0.2617
# Epoch 67/75
# 300/300 [==============================] - 5s 15ms/step - loss: 0.2594 - val_loss: 0.2618
# Epoch 68/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2594 - val_loss: 0.2616
# Epoch 69/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2594 - val_loss: 0.2617
# Epoch 70/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2594 - val_loss: 0.2617
# Epoch 71/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2594 - val_loss: 0.2619
# Epoch 72/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2594 - val_loss: 0.2616
# Epoch 73/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2594 - val_loss: 0.2617
# Epoch 74/75
# 300/300 [==============================] - 4s 15ms/step - loss: 0.2594 - val_loss: 0.2617
# Epoch 75/75
# 300/300 [==============================] - 4s 14ms/step - loss: 0.2594 - val_loss: 0.2618

# %%
fmnist_predictions = autoencoder.predict(noisy_fmnist_test_data)
#display(noisy_fmnist_test_data, fmnist_predictions)
mnist_predictions = autoencoder.predict(noisy_mnist_test_data)
#display(noisy_mnist_test_data, mnist_predictions)

# %%
display(noisy_fmnist_test_data, fmnist_predictions)
display(noisy_mnist_test_data, mnist_predictions)
